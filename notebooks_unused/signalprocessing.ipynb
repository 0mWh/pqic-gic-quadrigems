# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('..')
from should_be_stdlib import *

# %%
plt.plot(
    x := np.array([3, 4.2, 6, 8.5, 12, 17, 24, 33.9, 48]),
    y := np.random.uniform(low=0.1, high=10, size=len(x))
)

bits = 3

plt.plot(
    xlg := resample_log(x, 1<<bits),
    ylg := resample_log(y, 1<<bits),
)

plt.plot(
    xln := resample(x, 1<<bits),
    yln := resample(y, 1<<bits),
)

# plt.plot(xln, ylg)
# plt.plot(xlg, yln)
